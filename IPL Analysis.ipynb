# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #### Load DataSet

# %%
df = pd.read_csv('IPLData.csv')
df
# Out:
#          Player Name       Team Nationality Player_Type  Capped  \
# 0     Shikhar Dhawan     Punjab      Indian      Batter       1
# 1      Shreyas Iyer     Kolkata      Indian      Batter       1
# 2     Faf Du Plessis  Bangalore    Overseas      Batter       1
# 3     Manish Pandey     Lucknow      Indian      Batter       1
# 4    Shimron Hetmyer  Rajasthan    Overseas      Batter       1
# ..               ...        ...         ...         ...     ...
# 230     Ravi Bishnoi    Lucknow      Indian    Bowlers        1
# 231  Ruturaj Gaikwad    Chennai      Indian      Batter       1
# 232    Sunil Narine     Kolkata    Overseas  Allrounder       1
# 233  Kieron Pollard      Mumbai    Overseas  Allrounder       1
# 234    Anrich Nortje      Delhi    Overseas    Bowlers        1
#
#      Matches_Played    Runs  Average  Strike_Rate  Wickets  Bowling_average  \
# 0             192.0  5783.0    34.63       126.60      4.0            16.50
# ...

# %%
# Get Description
df.describe()
# Out:
#            Capped  Matches_Played         Runs     Average  Strike_Rate  \
# count  235.000000      215.000000   165.000000  161.000000   163.000000
# mean     0.838298       43.897674   840.575758   21.792391   121.009939
# std      0.561802       48.695302  1270.341831   11.664156    30.739189
# min      0.000000        1.000000     0.000000    0.000000     0.000000
# 25%      0.500000       11.500000    67.000000   13.800000   112.635000
# 50%      1.000000       25.000000   289.000000   22.410000   128.630000
# 75%      1.000000       56.000000   954.000000   29.300000   137.550000
# max      2.000000      220.000000  6283.000000   58.500000   190.240000
#
#           Wickets  Bowling_average     Economy  Bowling_Strike_Rate  \
# count  140.000000       135.000000  143.000000           119.000000
# mean    31.485714        32.907185    8.223182            24.686134
# std     36.872420        18.191441    1.223541            12.982049
# ...

# %%
# finding(counting)  na values in each column 
df.isna().sum()
# Out:
# Player Name              0
# Team                     0
# Nationality              0
# Player_Type              0
# Capped                   0
# Matches_Played          20
# Runs                    70
# Average                 74
# Strike_Rate             72
# Wickets                 95
# Bowling_average        100
# Economy                 92
# Bowling_Strike_Rate    116
# Catches                208
# Run_outs               208
# Stumps                 208
# dtype: int64

# %%
# Get information of the DataSet
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Player Name          235 non-null    object
#  1   Team                 235 non-null    object
#  2   Nationality          235 non-null    object
#  3   Player_Type          235 non-null    object
#  4   Capped               235 non-null    int64
#  5   Matches_Played       215 non-null    float64
#  6   Runs                 165 non-null    float64
#  7   Average              161 non-null    float64
#  8   Strike_Rate          163 non-null    float64
#  9   Wickets              140 non-null    float64
#  10  Bowling_average      135 non-null    float64
#  11  Economy              143 non-null    float64
#  12  Bowling_Strike_Rate  119 non-null    float64
#  13  Catches              27 non-null     float64
#  14  Run_outs             27 non-null     float64
# ...

# %%
#capped Batters
batters = df.loc[(df['Player_Type'] =='Batter')]
batters_new = batters.loc[(batters["Capped"]==1)]

Capped_Batters = batters_new[['Player Name','Team','Nationality','Matches_Played','Runs','Average','Strike_Rate']]
Capped_Batters.head()
# Out:
#        Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 0   Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
# 1    Shreyas Iyer     Kolkata      Indian            87.0  2375.0    31.67
# 2   Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 3   Manish Pandey     Lucknow      Indian           154.0  3560.0    30.69
# 4  Shimron Hetmyer  Rajasthan    Overseas            31.0   517.0    25.85
#
#    Strike_Rate
# 0       126.60
# 1       123.96
# 2       131.09
# 3       121.83
# 4       151.17

# %%
keepers = df.loc[(df["Player_Type"] == 'Keeper')]
keepers_new = keepers.loc[(keepers["Capped"]==1)]
Capped_keepers = keepers_new[['Player Name','Team','Nationality','Matches_Played','Runs','Average','Strike_Rate','Catches','Run_outs','Stumps']]
Capped_keepers
# Out:
#            Player Name       Team Nationality  Matches_Played    Runs  \
# 105    Quinton De Kock    Lucknow    Overseas            77.0  2256.0
# 106      Ambati Rayudu    Chennai      Indian           175.0  3916.0
# 107       Ishan Kishan     Mumbai      Indian            61.0  1452.0
# 108     Jonny Bairstow     Punjab    Overseas            28.0  1038.0
# 109     Dinesh Karthik  Bangalore      Indian           213.0  4046.0
# 110   Nicholas Pooran   Hyderabad    Overseas            33.0   606.0
# 111          KS Bharat      Delhi      Indian             8.0   191.0
# 112         Anuj Rawat  Bangalore      Indian             1.0     0.0
# 113  Prabhsimran Singh     Punjab      Indian             5.0    50.0
# 114   Sheldon Jackson     Kolkata    Overseas             4.0    38.0
# 117      Sam Billings     Kolkata    Overseas            22.0   334.0
# 118   Wridhhiman Saha     Gujarat      Indian           133.0  2110.0
# ...

# %%
all_rounders = df.loc[(df["Player_Type"] == "Allrounder")]
all_rounders_new = all_rounders.loc[(all_rounders["Capped"]==1)]
Capped_Allrounders = all_rounders_new[['Player Name','Team','Nationality','Matches_Played','Runs','Average','Strike_Rate','Wickets','Bowling_average','Economy','Bowling_Strike_Rate']]
Capped_Allrounders
# Out:
#               Player Name       Team Nationality  Matches_Played    Runs  \
# 127  Ravichandran Ashwin   Rajasthan      Indian           167.0   456.0
# 128          Pat Cummins     Kolkata    Overseas            37.0   316.0
# 129         Dwayne Bravo     Chennai    Overseas           151.0  1537.0
# 130          Nitish Rana     Kolkata      Indian            77.0  1820.0
# 131          Jason Holder    Lucknow    Overseas            26.0   189.0
# 132         Harshal Patel  Bangalore      Indian            63.0   187.0
# 133          Deepak Hooda    Lucknow      Indian            80.0   785.0
# 135     Washington Sundar  Hyderabad      Indian            42.0   217.0
# 136         Krunal Pandya    Lucknow      Indian            84.0  1143.0
# 137        Mitchell Marsh      Delhi    Overseas            21.0   225.0
# 138           Riyan Parag  Rajasthan      Indian            30.0   339.0
# 139      Abhishek Sharma   Hyderabad      Indian            22.0   241.0
# ...

# %%
# Fill the null values for batters , keepers and all rounders

Capped_Batters = Capped_Batters.fillna(0)
Capped_keepers = Capped_keepers.fillna(0)
Capped_Allrounders = Capped_Allrounders.fillna(0)

# %% [markdown]
# ### Batters

# %%
Capped_Batters
# Out:
#           Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 0      Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
# 1       Shreyas Iyer     Kolkata      Indian            87.0  2375.0    31.67
# 2      Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 3      Manish Pandey     Lucknow      Indian           154.0  3560.0    30.69
# 4     Shimron Hetmyer  Rajasthan    Overseas            31.0   517.0    25.85
# 5       Robin Uthappa    Chenai       Indian           193.0  4722.0    27.94
# 6           Jason Roy    Gujarat    Overseas            13.0   329.0    29.91
# 7    Devdutt Padikkal  Rajasthan      Indian            29.0   884.0    31.57
# 8         Priyam Garg  Hyderabad      Indian            19.0   205.0    14.64
# 12     Rahul Tripathi  Hyderabad      Indian            62.0  1385.0    26.13
# 13      Aiden Markram  Hyderabad    Overseas             6.0   146.0    29.30
# ...

# %%
# Fetch the batters on the basis of Average 

top_batters = Capped_Batters.loc[(Capped_Batters["Average"] >= 31)]
top_batters
# Out:
#           Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 0      Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
# 1       Shreyas Iyer     Kolkata      Indian            87.0  2375.0    31.67
# 2      Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 7    Devdutt Padikkal  Rajasthan      Indian            29.0   884.0    31.57
# 14    Ajinkya Rahane     Kolkata      Indian           151.0  3941.0    31.53
# 19      David Warner       Delhi    Overseas           150.0  5449.0    41.60
# 26      David Miller     Gujarat    Overseas            89.0  1974.0    32.90
# 205     Rohit Sharma      Mumbai      Indian           213.0  5611.0    31.17
# 207   Kane Williamson  Hyderabad    Overseas            63.0  1885.0    40.11
# 208       Virat Kohli  Bangalore      Indian           207.0  6283.0    37.40
# 212         KL Rahul     Lucknow      Indian            94.0  3273.0    47.43
# ...

# %%
# Batters on the basis of Average, Strike Rate, Runs , Matches Played

top_batters_average = top_batters.sort_values('Average',ascending = False)
top_batters_strikerate = top_batters.sort_values('Strike_Rate',ascending = False)
top_batters_runs = top_batters.sort_values('Runs',ascending = False)
top_batters_matches = top_batters.sort_values('Matches_Played',ascending = False)

# %%
top_batters_average
# Out:
#           Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 212         KL Rahul     Lucknow      Indian            94.0  3273.0    47.43
# 231   Ruturaj Gaikwad    Chennai      Indian            22.0   839.0    46.61
# 19      David Warner       Delhi    Overseas           150.0  5449.0    41.60
# 207   Kane Williamson  Hyderabad    Overseas            63.0  1885.0    40.11
# 208       Virat Kohli  Bangalore      Indian           207.0  6283.0    37.40
# 2      Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 0      Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
# 26      David Miller     Gujarat    Overseas            89.0  1974.0    32.90
# 1       Shreyas Iyer     Kolkata      Indian            87.0  2375.0    31.67
# 7    Devdutt Padikkal  Rajasthan      Indian            29.0   884.0    31.57
# 14    Ajinkya Rahane     Kolkata      Indian           151.0  3941.0    31.53
# ...

# %%
top_batters_strikerate
# Out:
#           Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 19      David Warner       Delhi    Overseas           150.0  5449.0    41.60
# 26      David Miller     Gujarat    Overseas            89.0  1974.0    32.90
# 212         KL Rahul     Lucknow      Indian            94.0  3273.0    47.43
# 231   Ruturaj Gaikwad    Chennai      Indian            22.0   839.0    46.61
# 207   Kane Williamson  Hyderabad    Overseas            63.0  1885.0    40.11
# 2      Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 205     Rohit Sharma      Mumbai      Indian           213.0  5611.0    31.17
# 208       Virat Kohli  Bangalore      Indian           207.0  6283.0    37.40
# 0      Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
# 7    Devdutt Padikkal  Rajasthan      Indian            29.0   884.0    31.57
# 1       Shreyas Iyer     Kolkata      Indian            87.0  2375.0    31.67
# ...

# %%
top_batters_runs
# Out:
#           Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 208       Virat Kohli  Bangalore      Indian           207.0  6283.0    37.40
# 0      Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
# 205     Rohit Sharma      Mumbai      Indian           213.0  5611.0    31.17
# 19      David Warner       Delhi    Overseas           150.0  5449.0    41.60
# 14    Ajinkya Rahane     Kolkata      Indian           151.0  3941.0    31.53
# 212         KL Rahul     Lucknow      Indian            94.0  3273.0    47.43
# 2      Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 1       Shreyas Iyer     Kolkata      Indian            87.0  2375.0    31.67
# 26      David Miller     Gujarat    Overseas            89.0  1974.0    32.90
# 207   Kane Williamson  Hyderabad    Overseas            63.0  1885.0    40.11
# 229      Shubman Gill    Gujarat      Indian            58.0  1417.0    31.49
# ...

# %%
top_batters_matches
# Out:
#           Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 205     Rohit Sharma      Mumbai      Indian           213.0  5611.0    31.17
# 208       Virat Kohli  Bangalore      Indian           207.0  6283.0    37.40
# 0      Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
# 14    Ajinkya Rahane     Kolkata      Indian           151.0  3941.0    31.53
# 19      David Warner       Delhi    Overseas           150.0  5449.0    41.60
# 2      Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 212         KL Rahul     Lucknow      Indian            94.0  3273.0    47.43
# 26      David Miller     Gujarat    Overseas            89.0  1974.0    32.90
# 1       Shreyas Iyer     Kolkata      Indian            87.0  2375.0    31.67
# 207   Kane Williamson  Hyderabad    Overseas            63.0  1885.0    40.11
# 229      Shubman Gill    Gujarat      Indian            58.0  1417.0    31.49
# ...

# %% [markdown]
# ### All Rounders

# %%
Capped_Allrounders
# Out:
#               Player Name       Team Nationality  Matches_Played    Runs  \
# 127  Ravichandran Ashwin   Rajasthan      Indian           167.0   456.0
# 128          Pat Cummins     Kolkata    Overseas            37.0   316.0
# 129         Dwayne Bravo     Chennai    Overseas           151.0  1537.0
# 130          Nitish Rana     Kolkata      Indian            77.0  1820.0
# 131          Jason Holder    Lucknow    Overseas            26.0   189.0
# 132         Harshal Patel  Bangalore      Indian            63.0   187.0
# 133          Deepak Hooda    Lucknow      Indian            80.0   785.0
# 135     Washington Sundar  Hyderabad      Indian            42.0   217.0
# 136         Krunal Pandya    Lucknow      Indian            84.0  1143.0
# 137        Mitchell Marsh      Delhi    Overseas            21.0   225.0
# 138           Riyan Parag  Rajasthan      Indian            30.0   339.0
# 139      Abhishek Sharma   Hyderabad      Indian            22.0   241.0
# ...

# %%
#  Fetch the All Rounders on the basis of Strike Rate
 
top_allrounders = Capped_Allrounders.loc[(Capped_Allrounders['Strike_Rate'] >=135.0)]
top_allrounders
# Out:
#              Player Name       Team Nationality  Matches_Played    Runs  \
# 128         Pat Cummins     Kolkata    Overseas            37.0   316.0
# 136        Krunal Pandya    Lucknow      Indian            84.0  1143.0
# 139     Abhishek Sharma   Hyderabad      Indian            22.0   241.0
# 140       Sarfaraz Khan       Delhi      Indian            40.0   441.0
# 154           K Gowtham     Lucknow      Indian            24.0   186.0
# 165         Jofra Archer     Mumbai    Overseas            35.0   195.0
# 168  Sherfane Rutherford  Bangalore    Overseas             7.0    73.0
# 169    Mithchel Santner     Chennai    Overseas             6.0    32.0
# 195       Mohammad Nabi     Kolkata    Overseas            17.0   180.0
# 202           Aman Khan     Kolkata      Indian             5.0    40.0
# 204        Andre Russell    Kolkata    Overseas            84.0  1700.0
# 211        Hardik Pandya    Gujarat      Indian            92.0  1476.0
# ...

# %%
# All rounders sorted on the basis of Average, Strike Rate, Runs , Matches, Bowling Average, Bowling Strike Rate, Wickets, Economy, Matches

top_allrounders_average = top_allrounders.sort_values('Average',ascending = False)
top_allrounders_strikerate = top_allrounders.sort_values('Strike_Rate',ascending = False)
top_allrounders_runs = top_allrounders.sort_values('Runs',ascending = False)
top_allrounders_matches = top_allrounders.sort_values('Matches_Played',ascending = False)
top_allrounders_bowling_average = top_allrounders.sort_values('Bowling_average',ascending= False)
top_allrounders_bowling_strikerate = top_allrounders.sort_values('Bowling_Strike_Rate')
top_allrounders_wickets = top_allrounders.sort_values('Wickets',ascending = False)
top_allrounders_economy = top_allrounders.sort_values('Economy')
top_allrounders_matches = top_allrounders.sort_values('Matches_Played',ascending = False)

# %%
top_allrounders_average
# Out:
#              Player Name       Team Nationality  Matches_Played    Runs  \
# 169    Mithchel Santner     Chennai    Overseas             6.0    32.0
# 233      Kieron Pollard      Mumbai    Overseas           178.0  3268.0
# 204        Andre Russell    Kolkata    Overseas            84.0  1700.0
# 222       Marcus Stoinis    Lucknow    Overseas            56.0   914.0
# 211        Hardik Pandya    Gujarat      Indian            92.0  1476.0
# 218         Glen Maxwell  Bangalore    Overseas            97.0  2018.0
# 140       Sarfaraz Khan       Delhi      Indian            40.0   441.0
# 223            Moeen Ali    Chennai    Overseas            34.0   666.0
# 136        Krunal Pandya    Lucknow      Indian            84.0  1143.0
# 128         Pat Cummins     Kolkata    Overseas            37.0   316.0
# 139     Abhishek Sharma   Hyderabad      Indian            22.0   241.0
# 232        Sunil Narine     Kolkata    Overseas           134.0   954.0
# ...

# %%
top_allrounders_strikerate
# Out:
#              Player Name       Team Nationality  Matches_Played    Runs  \
# 204        Andre Russell    Kolkata    Overseas            84.0  1700.0
# 154           K Gowtham     Lucknow      Indian            24.0   186.0
# 232        Sunil Narine     Kolkata    Overseas           134.0   954.0
# 165         Jofra Archer     Mumbai    Overseas            35.0   195.0
# 211        Hardik Pandya    Gujarat      Indian            92.0  1476.0
# 218         Glen Maxwell  Bangalore    Overseas            97.0  2018.0
# 195       Mohammad Nabi     Kolkata    Overseas            17.0   180.0
# 233      Kieron Pollard      Mumbai    Overseas           178.0  3268.0
# 202           Aman Khan     Kolkata      Indian             5.0    40.0
# 223            Moeen Ali    Chennai    Overseas            34.0   666.0
# 128         Pat Cummins     Kolkata    Overseas            37.0   316.0
# 139     Abhishek Sharma   Hyderabad      Indian            22.0   241.0
# ...

# %%
top_allrounders_runs
# Out:
#              Player Name       Team Nationality  Matches_Played    Runs  \
# 233      Kieron Pollard      Mumbai    Overseas           178.0  3268.0
# 218         Glen Maxwell  Bangalore    Overseas            97.0  2018.0
# 204        Andre Russell    Kolkata    Overseas            84.0  1700.0
# 211        Hardik Pandya    Gujarat      Indian            92.0  1476.0
# 136        Krunal Pandya    Lucknow      Indian            84.0  1143.0
# 232        Sunil Narine     Kolkata    Overseas           134.0   954.0
# 222       Marcus Stoinis    Lucknow    Overseas            56.0   914.0
# 223            Moeen Ali    Chennai    Overseas            34.0   666.0
# 140       Sarfaraz Khan       Delhi      Indian            40.0   441.0
# 128         Pat Cummins     Kolkata    Overseas            37.0   316.0
# 139     Abhishek Sharma   Hyderabad      Indian            22.0   241.0
# 221          Rashid Khan    Gujarat    Overseas            76.0   222.0
# ...

# %%
top_allrounders_matches
# Out:
#              Player Name       Team Nationality  Matches_Played    Runs  \
# 233      Kieron Pollard      Mumbai    Overseas           178.0  3268.0
# 232        Sunil Narine     Kolkata    Overseas           134.0   954.0
# 218         Glen Maxwell  Bangalore    Overseas            97.0  2018.0
# 211        Hardik Pandya    Gujarat      Indian            92.0  1476.0
# 136        Krunal Pandya    Lucknow      Indian            84.0  1143.0
# 204        Andre Russell    Kolkata    Overseas            84.0  1700.0
# 221          Rashid Khan    Gujarat    Overseas            76.0   222.0
# 222       Marcus Stoinis    Lucknow    Overseas            56.0   914.0
# 140       Sarfaraz Khan       Delhi      Indian            40.0   441.0
# 128         Pat Cummins     Kolkata    Overseas            37.0   316.0
# 165         Jofra Archer     Mumbai    Overseas            35.0   195.0
# 223            Moeen Ali    Chennai    Overseas            34.0   666.0
# ...

# %%
top_allrounders_bowling_average
# Out:
#              Player Name       Team Nationality  Matches_Played    Runs  \
# 168  Sherfane Rutherford  Bangalore    Overseas             7.0    73.0
# 154           K Gowtham     Lucknow      Indian            24.0   186.0
# 218         Glen Maxwell  Bangalore    Overseas            97.0  2018.0
# 136        Krunal Pandya    Lucknow      Indian            84.0  1143.0
# 222       Marcus Stoinis    Lucknow    Overseas            56.0   914.0
# 233      Kieron Pollard      Mumbai    Overseas           178.0  3268.0
# 195       Mohammad Nabi     Kolkata    Overseas            17.0   180.0
# 211        Hardik Pandya    Gujarat      Indian            92.0  1476.0
# 128         Pat Cummins     Kolkata    Overseas            37.0   316.0
# 223            Moeen Ali    Chennai    Overseas            34.0   666.0
# 204        Andre Russell    Kolkata    Overseas            84.0  1700.0
# 139     Abhishek Sharma   Hyderabad      Indian            22.0   241.0
# ...

# %%
top_allrounders_bowling_strikerate
# Out:
#              Player Name       Team Nationality  Matches_Played    Runs  \
# 140       Sarfaraz Khan       Delhi      Indian            40.0   441.0
# 202           Aman Khan     Kolkata      Indian             5.0    40.0
# 204        Andre Russell    Kolkata    Overseas            84.0  1700.0
# 165         Jofra Archer     Mumbai    Overseas            35.0   195.0
# 139     Abhishek Sharma   Hyderabad      Indian            22.0   241.0
# 221          Rashid Khan    Gujarat    Overseas            76.0   222.0
# 222       Marcus Stoinis    Lucknow    Overseas            56.0   914.0
# 211        Hardik Pandya    Gujarat      Indian            92.0  1476.0
# 169    Mithchel Santner     Chennai    Overseas             6.0    32.0
# 233      Kieron Pollard      Mumbai    Overseas           178.0  3268.0
# 232        Sunil Narine     Kolkata    Overseas           134.0   954.0
# 128         Pat Cummins     Kolkata    Overseas            37.0   316.0
# ...

# %%
top_allrounders_wickets
# Out:
#              Player Name       Team Nationality  Matches_Played    Runs  \
# 232        Sunil Narine     Kolkata    Overseas           134.0   954.0
# 221          Rashid Khan    Gujarat    Overseas            76.0   222.0
# 204        Andre Russell    Kolkata    Overseas            84.0  1700.0
# 233      Kieron Pollard      Mumbai    Overseas           178.0  3268.0
# 136        Krunal Pandya    Lucknow      Indian            84.0  1143.0
# 165         Jofra Archer     Mumbai    Overseas            35.0   195.0
# 211        Hardik Pandya    Gujarat      Indian            92.0  1476.0
# 128         Pat Cummins     Kolkata    Overseas            37.0   316.0
# 222       Marcus Stoinis    Lucknow    Overseas            56.0   914.0
# 218         Glen Maxwell  Bangalore    Overseas            97.0  2018.0
# 223            Moeen Ali    Chennai    Overseas            34.0   666.0
# 195       Mohammad Nabi     Kolkata    Overseas            17.0   180.0
# ...

# %%
top_allrounders_economy
# Out:
#              Player Name       Team Nationality  Matches_Played    Runs  \
# 140       Sarfaraz Khan       Delhi      Indian            40.0   441.0
# 221          Rashid Khan    Gujarat    Overseas            76.0   222.0
# 232        Sunil Narine     Kolkata    Overseas           134.0   954.0
# 223            Moeen Ali    Chennai    Overseas            34.0   666.0
# 169    Mithchel Santner     Chennai    Overseas             6.0    32.0
# 202           Aman Khan     Kolkata      Indian             5.0    40.0
# 165         Jofra Archer     Mumbai    Overseas            35.0   195.0
# 195       Mohammad Nabi     Kolkata    Overseas            17.0   180.0
# 136        Krunal Pandya    Lucknow      Indian            84.0  1143.0
# 139     Abhishek Sharma   Hyderabad      Indian            22.0   241.0
# 128         Pat Cummins     Kolkata    Overseas            37.0   316.0
# 154           K Gowtham     Lucknow      Indian            24.0   186.0
# ...

# %%
top_allrounders_matches
# Out:
#              Player Name       Team Nationality  Matches_Played    Runs  \
# 233      Kieron Pollard      Mumbai    Overseas           178.0  3268.0
# 232        Sunil Narine     Kolkata    Overseas           134.0   954.0
# 218         Glen Maxwell  Bangalore    Overseas            97.0  2018.0
# 211        Hardik Pandya    Gujarat      Indian            92.0  1476.0
# 136        Krunal Pandya    Lucknow      Indian            84.0  1143.0
# 204        Andre Russell    Kolkata    Overseas            84.0  1700.0
# 221          Rashid Khan    Gujarat    Overseas            76.0   222.0
# 222       Marcus Stoinis    Lucknow    Overseas            56.0   914.0
# 140       Sarfaraz Khan       Delhi      Indian            40.0   441.0
# 128         Pat Cummins     Kolkata    Overseas            37.0   316.0
# 165         Jofra Archer     Mumbai    Overseas            35.0   195.0
# 223            Moeen Ali    Chennai    Overseas            34.0   666.0
# ...

# %% [markdown]
# ### Keepers

# %%
Capped_keepers
# Out:
#            Player Name       Team Nationality  Matches_Played    Runs  \
# 105    Quinton De Kock    Lucknow    Overseas            77.0  2256.0
# 106      Ambati Rayudu    Chennai      Indian           175.0  3916.0
# 107       Ishan Kishan     Mumbai      Indian            61.0  1452.0
# 108     Jonny Bairstow     Punjab    Overseas            28.0  1038.0
# 109     Dinesh Karthik  Bangalore      Indian           213.0  4046.0
# 110   Nicholas Pooran   Hyderabad    Overseas            33.0   606.0
# 111          KS Bharat      Delhi      Indian             8.0   191.0
# 112         Anuj Rawat  Bangalore      Indian             1.0     0.0
# 113  Prabhsimran Singh     Punjab      Indian             5.0    50.0
# 114   Sheldon Jackson     Kolkata    Overseas             4.0    38.0
# 117      Sam Billings     Kolkata    Overseas            22.0   334.0
# 118   Wridhhiman Saha     Gujarat      Indian           133.0  2110.0
# ...

# %%
# Fetch the keepers based on Average
top_keepers = Capped_keepers.loc[(Capped_keepers["Average"]>=25.00)]
top_keepers
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
# 107     Ishan Kishan     Mumbai      Indian            61.0  1452.0    28.50
# 108   Jonny Bairstow     Punjab    Overseas            28.0  1038.0    41.50
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
# 111        KS Bharat      Delhi      Indian             8.0   191.0    38.20
# 206    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 209     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 213         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 219       Jos Butler  Rajasthan    Overseas            65.0  1968.0    35.14
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 105       130.90     53.0       0.0    14.0
# ...

# %%
# Keepers sorted on the basis of Average, Strike Rate, Runs, Mathces Played, Catches , Run Out, Stumps
top_keepers_average = top_keepers.sort_values('Average',ascending = False)
top_keepers_strikerate = top_keepers.sort_values('Strike_Rate',ascending = False)
top_keepers_runs = top_keepers.sort_values('Runs',ascending = False)
top_keepers_matches = top_keepers.sort_values('Matches_Played',ascending = False)
top_keepers_catches = top_keepers.sort_values('Catches',ascending = False)
top_keepers_runouts = top_keepers.sort_values('Run_outs',ascending = False)
top_keepers_stumps = top_keepers.sort_values('Stumps',ascending = False)

# %%
top_keepers_average
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 108   Jonny Bairstow     Punjab    Overseas            28.0  1038.0    41.50
# 213         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 111        KS Bharat      Delhi      Indian             8.0   191.0    38.20
# 206    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 219       Jos Butler  Rajasthan    Overseas            65.0  1968.0    35.14
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
# 209     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 107     Ishan Kishan     Mumbai      Indian            61.0  1452.0    28.50
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 108       142.20     18.0       1.0     4.0
# ...

# %%
top_keepers_strikerate
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 219       Jos Butler  Rajasthan    Overseas            65.0  1968.0    35.14
# 206    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 108   Jonny Bairstow     Punjab    Overseas            28.0  1038.0    41.50
# 107     Ishan Kishan     Mumbai      Indian            61.0  1452.0    28.50
# 213         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 209     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
# 111        KS Bharat      Delhi      Indian             8.0   191.0    38.20
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 219       150.00     34.0       3.0     1.0
# ...

# %%
top_keepers_runs
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 213         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
# 209     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 206    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
# 219       Jos Butler  Rajasthan    Overseas            65.0  1968.0    35.14
# 107     Ishan Kishan     Mumbai      Indian            61.0  1452.0    28.50
# 108   Jonny Bairstow     Punjab    Overseas            28.0  1038.0    41.50
# 111        KS Bharat      Delhi      Indian             8.0   191.0    38.20
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 213       135.80    126.0      21.0    39.0
# ...

# %%
top_keepers_matches
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 213         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
# 209     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 206    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
# 219       Jos Butler  Rajasthan    Overseas            65.0  1968.0    35.14
# 107     Ishan Kishan     Mumbai      Indian            61.0  1452.0    28.50
# 108   Jonny Bairstow     Punjab    Overseas            28.0  1038.0    41.50
# 111        KS Bharat      Delhi      Indian             8.0   191.0    38.20
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 213       135.80    126.0      21.0    39.0
# ...

# %%
top_keepers_catches
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 213         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
# 209     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
# 206    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
# 219       Jos Butler  Rajasthan    Overseas            65.0  1968.0    35.14
# 107     Ishan Kishan     Mumbai      Indian            61.0  1452.0    28.50
# 108   Jonny Bairstow     Punjab    Overseas            28.0  1038.0    41.50
# 111        KS Bharat      Delhi      Indian             8.0   191.0    38.20
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 213       135.80    126.0      21.0    39.0
# ...

# %%
top_keepers_runouts
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 213         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
# 209     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 206    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 219       Jos Butler  Rajasthan    Overseas            65.0  1968.0    35.14
# 107     Ishan Kishan     Mumbai      Indian            61.0  1452.0    28.50
# 108   Jonny Bairstow     Punjab    Overseas            28.0  1038.0    41.50
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
# 111        KS Bharat      Delhi      Indian             8.0   191.0    38.20
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 213       135.80    126.0      21.0    39.0
# ...

# %%
top_keepers_stumps
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 213         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
# 206    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 209     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 108   Jonny Bairstow     Punjab    Overseas            28.0  1038.0    41.50
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
# 107     Ishan Kishan     Mumbai      Indian            61.0  1452.0    28.50
# 111        KS Bharat      Delhi      Indian             8.0   191.0    38.20
# 219       Jos Butler  Rajasthan    Overseas            65.0  1968.0    35.14
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 213       135.80    126.0      21.0    39.0
# ...

# %% [markdown]
# ### Visualization

# %% [markdown]
# #### Batsman

# %%
# Plot the data for Player Name and Runs
name = top_batters_runs['Player Name'].head(8)
strike = top_batters_runs['Runs'].head(8)
plt.figure(figsize=(15,15))
plt.bar(name,strike,data =top_batters_runs,color ='c')
plt.show()

# %%
# Plot the data for Player Name and Average
name = top_batters_average['Player Name'].head(8)
strike = top_batters_average['Average'].head(8)
plt.figure(figsize=(15,15))
plt.bar(name,strike,data =top_batters_average,color ='y')
plt.show()

# %%
# Plot the data for Player name and Strike Rate

name = top_batters_strikerate['Player Name'].head(8)
strike = top_batters_strikerate['Strike_Rate'].head(8)
plt.figure(figsize=(15,15))
plt.bar(name,strike,data =top_batters_strikerate,color ='m')
plt.show()

# %% [markdown]
# Top Batsman according to this analysis:
# 1. David Warner
# 2. Kl Rahul
# 3. Ruturaj Gaikwad

# %% [markdown]
# ##### Wicket Keepers

# %%
# Plot the data for Player Name and Average
name = top_keepers_average['Player Name'].head(8)
strike = top_keepers_average['Average'].head(8)
plt.figure(figsize=(15,15))
plt.bar(name,strike,data =top_keepers_average,color ='c')
plt.show()

# %%
# Plot the data for Player Name and Runs
name = top_keepers_runs['Player Name'].head(8)
strike = top_keepers_runs['Runs'].head(8)
plt.figure(figsize=(15,15))
plt.bar(name,strike,data =top_keepers_runs,color ='y')
plt.show()

# %%
# Plot the data for Playername and Strike Rate

name = top_keepers_strikerate['Player Name'].head(8)
strike = top_keepers_strikerate['Strike_Rate'].head(8)
plt.figure(figsize=(15,15))
plt.bar(name,strike,data =top_keepers_strikerate,color ='m')
plt.show()

# %%
#  Plot the data for Player Name and Catches
name = top_keepers_catches['Player Name'].head(8)
strike = top_keepers_catches['Catches'].head(8)
plt.figure(figsize=(15,15))
plt.bar(name,strike,data =top_keepers_catches,color ='b')
plt.show()

# %%
# Plot the data for Player Name and Run Out 
name = top_keepers_runouts['Player Name'].head(8)
strike = top_keepers_runouts['Run_outs'].head(8)
plt.figure(figsize=(15,15))
plt.bar(name,strike,data =top_keepers_runouts,color ='g')
plt.show()

# %%
#  Plot the data for Player Name and Stumps
name = top_keepers_stumps['Player Name'].head(8)
strike = top_keepers_stumps['Stumps'].head(8)
plt.figure(figsize=(15,15))
plt.bar(name,strike,data =top_keepers_stumps,color ='k')
plt.show()

# %% [markdown]
# Top Wicket Keepers according to this analysis:
# 1. MS Dhoni
# 2. Dinesh Kartik
# 3. Sanju Samson

# %% [markdown]
# #### Allrounders

# %%
#  Plot the data for Player Name and Average
name = top_allrounders_average['Player Name'].head(8)
strike = top_allrounders_average['Average'].head(8)
plt.figure(figsize=(15,15))
plt.bar(name,strike,data =top_allrounders_average,color ='c')
plt.show()

# %%
# Plot the data for Player Name and Strike Rate
name = top_allrounders_strikerate['Player Name'].head(8)
strike = top_allrounders_strikerate['Strike_Rate'].head(8)
plt.figure(figsize=(15,15))
plt.bar(name,strike,data =top_allrounders_strikerate,color ='y')
plt.show()

# %%
#  Plot the data for Player Name and Runs
name = top_allrounders_runs['Player Name'].head(8)
strike = top_allrounders_runs['Runs'].head(8)
plt.figure(figsize=(15,15))
plt.bar(name,strike,data =top_allrounders_runs,color ='m')
plt.show()

# %%
#  Plot the data for Player Name and Bowling Average
name = top_allrounders_bowling_average ['Player Name'].head(8)
strike = top_allrounders_bowling_average ['Bowling_average'].head(8)
plt.figure(figsize=(15,15))
plt.bar(name,strike,data =top_allrounders_bowling_average ,color ='c')
plt.show()

# %%
#  Plot the data for Player Name and Bowling Strike Rate
name = top_allrounders_bowling_strikerate  ['Player Name'].head(8)
strike = top_allrounders_bowling_strikerate  ['Bowling_Strike_Rate'].head(8)
plt.figure(figsize=(15,15))
plt.bar(name,strike,data =top_allrounders_bowling_strikerate  ,color ='g')
plt.show()

# %%
#  Plot the data for Player Name and Wickets
name = top_allrounders_wickets['Player Name'].head(8)
strike = top_allrounders_wickets['Wickets'].head(8)
plt.figure(figsize=(15,15))
plt.bar(name,strike,data =top_allrounders_wickets   ,color ='k')
plt.show()

# %% [markdown]
# Top All Rounders according to this analysis:
# 1. Andre Russell
# 2. Sunil Narine
# 3. K Gowtham
